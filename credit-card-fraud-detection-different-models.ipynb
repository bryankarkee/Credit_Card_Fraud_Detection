# %% [markdown]
# <html>
# <h1 style="text-align:center;color:red;background-color:powderblue;font-size:400%">Credit Card Fraud Detection</h1>
# </html>

# %% [markdown]
# <html>
#     <p style="border:4px solid violet;color:indigo;background-color:tan"><b>About Dataset :</b><br>
#  👉The dataset contains transactions made by credit cards in September 2013 by European cardholders.<br>
# 👉This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.<br><br>
# 👉It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-sensitive learning.<br>👉 Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise..</p>
# </html>

# %% [markdown]
# ## Data Manipulation <a class="anchor" id="sec1"></a>

# %% [markdown]
# ### Importing libraries

# %% [markdown]
# <html>
# <img src="https://newrelic.com/sites/default/files/wp_blog_inline_files/shutterstock_1352528811.jpg" alt="Computer man" style="width:150px;height:100px;"/>
# </html>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
#imported different libraries where we will be working with.

# %%
pd.set_option("display.max_rows", 100, "display.max_columns", 100)

# %% [markdown]
# ### Importing dataset <a class="anchor" id="sec1.1"></a>

# %%
df=pd.read_csv('C:/Users/pc/Downloads/Creditcard/creditcard.csv')

# %% [markdown]
# ### Dataset View <a class="anchor" id="sec1.2"></a>

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %% [markdown]
# ### Dataset Information <a class="anchor" id="sec1.3"></a>

# %% [markdown]
# <html>
# <p style="border:4px solid violet;color:indigo;background-color:tan">Here we can see that all the data types are in <b>float</b> type except 'Class' which is in <b>Binary</b> type.</p>
# </html>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# ### Summary Statistics <a class="anchor" id="sec1.4"></a>

# %% [markdown]
# <html>
# <p style="color:chocolate;font-size:150%;">
#     <b>Brief Information of different descriptive statistics-</b></p>
# <p style="border:4px solid violet;color:green;background-color:tan;">
#     *<b>Measures of Frequency</b>              :- Count, Percent, Frequency.<br>
#     *<b>Measures of Central Tendency</b>       :- Mean, Median, and Mode.<br>
#     *<b>Measures of Dispersion or Variation</b>:- Range(min,max),Variance, Standard Deviation.<br>
#     *<b>Measures of Position</b>               :- Percentile Ranks, Quartile Ranks.</p>
# </html>

# %%
df.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_2eb5a_row0_col0, #T_2eb5a_row0_col1, #T_2eb5a_row0_col2, #T_2eb5a_row0_col3, #T_2eb5a_row0_col4, #T_2eb5a_row0_col5, #T_2eb5a_row0_col6, #T_2eb5a_row0_col7, #T_2eb5a_row0_col8, #T_2eb5a_row0_col9, #T_2eb5a_row0_col10, #T_2eb5a_row0_col11, #T_2eb5a_row0_col12, #T_2eb5a_row0_col13, #T_2eb5a_row0_col14, #T_2eb5a_row0_col15, #T_2eb5a_row0_col16, #T_2eb5a_row0_col17, #T_2eb5a_row0_col18, #T_2eb5a_row0_col19, #T_2eb5a_row0_col20, #T_2eb5a_row0_col21, #T_2eb5a_row0_col22, #T_2eb5a_row0_col23, #T_2eb5a_row0_col24, #T_2eb5a_row0_col25, #T_2eb5a_row0_col26, #T_2eb5a_row0_col27, #T_2eb5a_row0_col28, #T_2eb5a_row0_col29, #T_2eb5a_row0_col30 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2eb5a_row1_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_2eb5a_row1_col1, #T_2eb5a_row1_col2, #T_2eb5a_row1_col3, #T_2eb5a_row1_col4, #T_2eb5a_row1_col5, #T_2eb5a_row1_col6, #T_2eb5a_row1_col7, #T_2eb5a_row1_col8, #T_2eb5a_row1_col9, #T_2eb5a_row1_col10, #T_2eb5a_row1_col11, #T_2eb5a_row1_col12, #T_2eb5a_row1_col13, #T_2eb5a_row1_col14, #T_2eb5a_row1_col15, #T_2eb5a_row1_col16, #T_2eb5a_row1_col17, #T_2eb5a_row1_col18, #T_2eb5a_row1_col19, #T_2eb5a_row1_col20, #T_2eb5a_row1_col21, #T_2eb5a_row1_col22, #T_2eb5a_row1_col23, #T_2eb5a_row1_col24, #T_2eb5a_row1_col25, #T_2eb5a_row1_col26, #T_2eb5a_row1_col27, #T_2eb5a_row1_col28, #T_2eb5a_row1_col29, #T_2eb5a_row1_col30, #T_2eb5a_row2_col1, #T_2eb5a_row2_col2, #T_2eb5a_row2_col3, #T_2eb5a_row2_col4, #T_2eb5a_row2_col5, #T_2eb5a_row2_col6, #T_2eb5a_row2_col7, #T_2eb5a_row2_col8, #T_2eb5a_row2_col9, #T_2eb5a_row2_col10, #T_2eb5a_row2_col11, #T_2eb5a_row2_col12, #T_2eb5a_row2_col13, #T_2eb5a_row2_col14, #T_2eb5a_row2_col15, #T_2eb5a_row2_col16, #T_2eb5a_row2_col17, #T_2eb5a_row2_col18, #T_2eb5a_row2_col19, #T_2eb5a_row2_col20, #T_2eb5a_row2_col21, #T_2eb5a_row2_col22, #T_2eb5a_row2_col23, #T_2eb5a_row2_col24, #T_2eb5a_row2_col25, #T_2eb5a_row2_col26, #T_2eb5a_row2_col27, #T_2eb5a_row2_col28, #T_2eb5a_row2_col29, #T_2eb5a_row2_col30, #T_2eb5a_row3_col0, #T_2eb5a_row3_col1, #T_2eb5a_row3_col2, #T_2eb5a_row3_col3, #T_2eb5a_row3_col4, #T_2eb5a_row3_col5, #T_2eb5a_row3_col6, #T_2eb5a_row3_col7, #T_2eb5a_row3_col8, #T_2eb5a_row3_col9, #T_2eb5a_row3_col10, #T_2eb5a_row3_col11, #T_2eb5a_row3_col12, #T_2eb5a_row3_col13, #T_2eb5a_row3_col14, #T_2eb5a_row3_col15, #T_2eb5a_row3_col16, #T_2eb5a_row3_col17, #T_2eb5a_row3_col18, #T_2eb5a_row3_col19, #T_2eb5a_row3_col20, #T_2eb5a_row3_col21, #T_2eb5a_row3_col22, #T_2eb5a_row3_col23, #T_2eb5a_row3_col24, #T_2eb5a_row3_col25, #T_2eb5a_row3_col26, #T_2eb5a_row3_col27, #T_2eb5a_row3_col28, #T_2eb5a_row3_col29, #T_2eb5a_row3_col30, #T_2eb5a_row4_col1, #T_2eb5a_row4_col2, #T_2eb5a_row4_col3, #T_2eb5a_row4_col4, #T_2eb5a_row4_col5, #T_2eb5a_row4_col6, #T_2eb5a_row4_col7, #T_2eb5a_row4_col8, #T_2eb5a_row4_col9, #T_2eb5a_row4_col10, #T_2eb5a_row4_col11, #T_2eb5a_row4_col12, #T_2eb5a_row4_col13, #T_2eb5a_row4_col14, #T_2eb5a_row4_col15, #T_2eb5a_row4_col16, #T_2eb5a_row4_col17, #T_2eb5a_row4_col18, #T_2eb5a_row4_col19, #T_2eb5a_row4_col20, #T_2eb5a_row4_col21, #T_2eb5a_row4_col22, #T_2eb5a_row4_col23, #T_2eb5a_row4_col24, #T_2eb5a_row4_col25, #T_2eb5a_row4_col26, #T_2eb5a_row4_col27, #T_2eb5a_row4_col28, #T_2eb5a_row4_col29, #T_2eb5a_row4_col30, #T_2eb5a_row5_col1, #T_2eb5a_row5_col2, #T_2eb5a_row5_col3, #T_2eb5a_row5_col4, #T_2eb5a_row5_col5, #T_2eb5a_row5_col6, #T_2eb5a_row5_col7, #T_2eb5a_row5_col8, #T_2eb5a_row5_col9, #T_2eb5a_row5_col10, #T_2eb5a_row5_col11, #T_2eb5a_row5_col12, #T_2eb5a_row5_col13, #T_2eb5a_row5_col14, #T_2eb5a_row5_col15, #T_2eb5a_row5_col16, #T_2eb5a_row5_col17, #T_2eb5a_row5_col18, #T_2eb5a_row5_col19, #T_2eb5a_row5_col20, #T_2eb5a_row5_col21, #T_2eb5a_row5_col22, #T_2eb5a_row5_col23, #T_2eb5a_row5_col24, #T_2eb5a_row5_col25, #T_2eb5a_row5_col26, #T_2eb5a_row5_col27, #T_2eb5a_row5_col28, #T_2eb5a_row5_col29, #T_2eb5a_row5_col30, #T_2eb5a_row6_col1, #T_2eb5a_row6_col2, #T_2eb5a_row6_col3, #T_2eb5a_row6_col4, #T_2eb5a_row6_col5, #T_2eb5a_row6_col6, #T_2eb5a_row6_col7, #T_2eb5a_row6_col8, #T_2eb5a_row6_col9, #T_2eb5a_row6_col10, #T_2eb5a_row6_col11, #T_2eb5a_row6_col12, #T_2eb5a_row6_col13, #T_2eb5a_row6_col14, #T_2eb5a_row6_col15, #T_2eb5a_row6_col16, #T_2eb5a_row6_col17, #T_2eb5a_row6_col18, #T_2eb5a_row6_col19, #T_2eb5a_row6_col20, #T_2eb5a_row6_col21, #T_2eb5a_row6_col22, #T_2eb5a_row6_col23, #T_2eb5a_row6_col24, #T_2eb5a_row6_col25, #T_2eb5a_row6_col26, #T_2eb5a_row6_col27, #T_2eb5a_row6_col28, #T_2eb5a_row6_col29, #T_2eb5a_row6_col30, #T_2eb5a_row7_col1, #T_2eb5a_row7_col2, #T_2eb5a_row7_col3, #T_2eb5a_row7_col4, #T_2eb5a_row7_col5, #T_2eb5a_row7_col6, #T_2eb5a_row7_col7, #T_2eb5a_row7_col8, #T_2eb5a_row7_col9, #T_2eb5a_row7_col10, #T_2eb5a_row7_col11, #T_2eb5a_row7_col12, #T_2eb5a_ro ...
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_2eb5a_row2_col0 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_2eb5a_row4_col0 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_2eb5a_row5_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_2eb5a_row6_col0 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_2eb5a_row7_col0 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_2eb5a_row7_col29 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# </style>
# <table id="T_2eb5a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2eb5a_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_2eb5a_level0_col1" class="col_heading level0 col1" >V1</th>
#       <th id="T_2eb5a_level0_col2" class="col_heading level0 col2" >V2</th>
#       <th id="T_2eb5a_level0_col3" class="col_heading level0 col3" >V3</th>
#       <th id="T_2eb5a_level0_col4" class="col_heading level0 col4" >V4</th>
#       <th id="T_2eb5a_level0_col5" class="col_heading level0 col5" >V5</th>
#       <th id="T_2eb5a_level0_col6" class="col_heading level0 col6" >V6</th>
#       <th id="T_2eb5a_level0_col7" class="col_heading level0 col7" >V7</th>
#       <th id="T_2eb5a_level0_col8" class="col_heading level0 col8" >V8</th>
#       <th id="T_2eb5a_level0_col9" class="col_heading level0 col9" >V9</th>
#       <th id="T_2eb5a_level0_col10" class="col_heading level0 col10" >V10</th>
#       <th id="T_2eb5a_level0_col11" class="col_heading level0 col11" >V11</th>
#       <th id="T_2eb5a_level0_col12" class="col_heading level0 col12" >V12</th>
#       <th id="T_2eb5a_level0_col13" class="col_heading level0 col13" >V13</th>
#       <th id="T_2eb5a_level0_col14" class="col_heading level0 col14" >V14</th>
#       <th id="T_2eb5a_level0_col15" class="col_heading level0 col15" >V15</th>
#       <th id="T_2eb5a_level0_col16" class="col_heading level0 col16" >V16</th>
#       <th id="T_2eb5a_level0_col17" class="col_heading level0 col17" >V17</th>
#       <th id="T_2eb5a_level0_col18" class="col_heading level0 col18" >V18</th>
#       <th id="T_2eb5a_level0_col19" class="col_heading level0 col19" >V19</th>
#       <th id="T_2eb5a_level0_col20" class="col_heading level0 col20" >V20</th>
#       <th id="T_2eb5a_level0_col21" class="col_heading level0 col21" >V21</th>
#       <th id="T_2eb5a_level0_col22" class="col_heading level0 col22" >V22</th>
#       <th id="T_2eb5a_level0_col23" class="col_heading level0 col23" >V23</th>
#       <th id="T_2eb5a_level0_col24" class="col_heading level0 col24" >V24</th>
#       <th id="T_2eb5a_level0_col25" class="col_heading level0 col25" >V25</th>
#       <th id="T_2eb5a_level0_col26" class="col_heading level0 col26" >V26</th>
#       <th id="T_2eb5a_level0_col27" class="col_heading level0 col27" >V27</th>
#       <th id="T_2eb5a_level0_col28" class="col_heading level0 col28" >V28</th>
#       <th id="T_2eb5a_level0_col29" class=

# %% [markdown]
# ### Checking for unique values in all attribute <a class="anchor" id="sec1.5"></a>

# %% [markdown]
# <html>
# <p style="border:4px solid violet;color:indigo;background-color:tan">Different numbers of distint values in each attribute. Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise </p>
# </html>

# %%
df.nunique().sort_values(ascending=True)
# Out:
# Class          2
# Amount     32767
# Time      124592
# V3        275663
# V28       275663
# V27       275663
# V26       275663
# V25       275663
# V24       275663
# V23       275663
# V22       275663
# V21       275663
# V20       275663
# V19       275663
# V18       275663
# V17       275663
# V16       275663
# V1        275663
# V14       275663
# V13       275663
# V12       275663
# V11       275663
# V10       275663
# V9        275663
# V8        275663
# V7        275663
# V6        275663
# V5        275663
# V4        275663
# V2        275663
# V15       275663
# dtype: int64

# %%
df.Class.unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ### Checking for missing values in each column <a class="anchor" id="sec1.6"></a>

# %% [markdown]
# <html>
# <p style="border:4px solid violet;color:indigo;background-color:tan">No such missing values in our dataset.<br>
# If you want to learn how to treat the missing values.Go through this link
# <a href="https://www.analyticsvidhya.com/blog/2021/10/handling-missing-value/">CLICK HERE</a></p>
# </html>

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ### percentage of missing values in each column <a class="anchor" id="sec1.7"></a>

# %%
pd.options.display.float_format = '{:,.2f} %'.format
print((df.isnull().sum()/len(df))*100)
pd.options.display.float_format = '{:,.2f}'.format
# Out:
# Time     0.00 %
# V1       0.00 %
# V2       0.00 %
# V3       0.00 %
# V4       0.00 %
# V5       0.00 %
# V6       0.00 %
# V7       0.00 %
# V8       0.00 %
# V9       0.00 %
# V10      0.00 %
# V11      0.00 %
# V12      0.00 %
# V13      0.00 %
# V14      0.00 %
# V15      0.00 %
# V16      0.00 %
# V17      0.00 %
# V18      0.00 %
# V19      0.00 %
# V20      0.00 %
# V21      0.00 %
# V22      0.00 %
# V23      0.00 %
# V24      0.00 %
# V25      0.00 %
# V26      0.00 %
# V27      0.00 %
# V28      0.00 %
# Amount   0.00 %
# Class    0.00 %
# dtype: float64

# %% [markdown]
# ## Data Visualization <a class="anchor" id="sec2"></a>

# %% [markdown]
# ### Missing Value Plot <a class="anchor" id="sec2.1"></a>

# %%
import missingno as msno

# %%
msno.matrix(df,labels=[df.columns],figsize=(30,16),fontsize=12)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Checking the data distribution of each Continuous variable  <a class="anchor" id="sec2.2"></a>

# %% [markdown]
# <html>
#
#   <br><b>What is skewed distribution?</b><br>
#     If one tail is longer than another, the distribution is skewed. These distributions are sometimes called asymmetric or asymmetrical distributions as they don’t show any kind of symmetry. Symmetry means that one half of the distribution is a mirror image of the other half. For example, the normal distribution is a symmetric distribution with no skew. The tails are exactly the same.<br>
#     <b>Left Skewed or Negatively Skewed</b>:- A left-skewed distribution has a long left tail. Left-skewed distributions are also called negatively-skewed distributions.(Mean&lt;Median&lt;Mode)<br>
#     <b>Right Skewed or Positively Skewed</b>:-A right-skewed distribution has a long right tail. Right-skewed distributions are also called positive-skew distributions.(Mean&gt;Median&gt;Mode)<br>
#     <b>Symmetric Distribution:-</b>A symmetric distribution is a type of distribution where the left side of the distribution mirrors the right side(Mean=Median=Mode).ex-Normal Distribution
#     </p>
# </html>

# %%
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(6,5, i+1)
    sns.histplot(data=df, x=col, ax=ax,color='red',kde=True)
plt.suptitle('Data distribution of continuous variables')
plt.tight_layout()

# %% [markdown]
# From the above graph we can see that there are a lot of attributes which are positively or negatively distributed.

# %% [markdown]
# ### Box Plot <a class="anchor" id="sec2.3"></a>

# %% [markdown]
# <html>
# <p style="color:chocolate;font-size:150%;">
#     <b>Box Plot-</b></p>
# <p style="border:4px solid violet;color:green;background-color:tan;text-align:center">
#     <b>What is Box Plot?</b><br>
#     <img src="https://lh5.googleusercontent.com/Wz6lRE49LVUVq18MyNj6pEwDgdVcHhyDqaG5yGMQX36hy3ZGSyH7fs4A4nbJojGR58k=w2400" alt="Computer man" style="width:800px;height:300px;" /><br>
#     In descriptive statistics, a box plot or boxplot is a method for graphically demonstrating the locality, spread and skewness groups of numerical data through their quartiles.</p><br>
#     <p style="border:4px solid violet;color:teal;background-color:tan;">
#         <b>How to interpret boxplot</b><br>
#     *Median: In the box plot, the median is displayed rather than the mean.<br>
#     * Q1: The first quartile (25%) position.<br>
#   * Q3: The third quartile (75%) position.<br>
#   *  Interquartile range (IQR): a measure of statistical dispersion, being equal to the difference between 75th and 25th percentiles. It represents how 50% of the points were dispersed.<br>
# * Lower and upper 1.5*IQR whiskers: These represent the limits and boundaries for the outliers.<br>
#   *  Outliers: Defined as observations that fall below Q1 − 1.5 IQR or above Q3 + 1.5 IQR. Outliers are displayed as dots or circles.
#
# </p>
# </html>

# %%
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(6,5, i+1)
    sns.boxplot(data=df, x=col, ax=ax,color='blue')
plt.suptitle('Box Plot of continuous variables')
plt.tight_layout()

# %%
#This function will replace the outliers with the median from the dataset
def outlier_treating(data,var):
    df=data.copy()#creating a copy of the data
    def outlier_detector(data):#detecting the outliers
        outliers=[]
        q1=np.percentile(data,25)
        q3=np.percentile(data,75)
        IQR=q3-q1
        lb=q1-(IQR*1.5)
        ub=q3+(IQR*1.5)
        for i,j in enumerate(data):
            if(j<lb or j>ub):
                outliers.append(i)
        return outliers
    for i in var:
        out_var=outlier_detector(df[i])#calling outlier_detector function 
        df.loc[out_var,i]=np.median(df[i])#replacing the outliers to the median
    return df

# %%
#selecting variables that have outliers
var=list(df.select_dtypes(include=['float64']).columns)

# %%
df=outlier_treating(df,var)

# %% [markdown]
# ### Data distribution after treating outliers <a class="anchor" id="sec2.4"></a>

# %% [markdown]
# <html>
# <p style="border:4px solid violet;color:indigo;background-color:tan">Now the Distribution plots look more symmetrical after treating the outliers.</p>
# </html>

# %%
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(6,5, i+1)
    sns.histplot(data=df, x=col, ax=ax,color='red',kde=True)
plt.suptitle('Data distribution of continuous variables')
plt.tight_layout()

# %% [markdown]
# ### Box Plot after treating outliers <a class="anchor" id="sec2.5"></a>

# %% [markdown]
# <html>
# <p style="border:4px solid violet;color:indigo;background-color:tan">Now our Box plots look better after treating the outliers.</p>
# </html>

# %%
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(6,5, i+1)
    sns.boxplot(data=df, x=col, ax=ax,color='blue')
plt.suptitle('Box Plot of continuous variables')
plt.tight_layout()

# %% [markdown]
# ### Heatmap <a class="anchor" id="sec2.6"></a>

# %% [markdown]
# <html>
# <p style="color:chocolate;font-size:150%;">
#     <b>Correlation Coefficient-</b></p>
#     <img src="https://lh6.googleusercontent.com/WJ-mqD3qf1j4DsE47HifHWf6d3H_2rrjbA0yVPpY-pIGapiZPX2uzM5l055oW-Nvp1U=w2400" alt="Computer man" style="width:800px;height:300px;"/>
#     <img src="https://lh5.googleusercontent.com/mJZDT-3QSQol0hs-opFs6NWUYMpFmiB7Hye-SQGaYJLiO-2LO2-a4358ljGymYUA4Yw=w2400" alt="Computer man" style="width:600px;height:200px;"/>
# </html>

# %% [markdown]
# <html>
# <p style="border:4px solid violet;color:indigo;background-color:tan">With this heatmap plot we can interpret which variable is how much correlated to other variable.</p>
# </html>

# %%
plt.figure(figsize=(18,18))
sns.heatmap(df.select_dtypes(include=['float']).corr(),annot=True,center = 0)
plt.show()

# %% [markdown]
# ### Bar Plot <a class="anchor" id="sec2.7"></a>

# %% [markdown]
# <html>
# <p style="border:4px solid violet;color:indigo;background-color:tan">Here we can look at each plot and see the contribution of each feature to the Class Variable.</p>
# </html>

# %%
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(6,5, i+1)
    sns.barplot(data=df,x='Class', y=col, ax=ax,edgecolor="black",palette='viridis_r')
plt.suptitle('Data distribution of continuous variables')
plt.tight_layout()

# %% [markdown]
# ### Analysing the target Variable <a class="anchor" id="sec2.4"></a>

# %% [markdown]
# #### Quality

# %% [markdown]
# <html>
# <p style="color:chocolate;font-size:150%;">
#     <b>Balanced and Imbalanced data-</b></p>
#     <img src="https://lh5.googleusercontent.com/KehyaPcGqhC5JHTYIHGbhmYcmwqoqM7bwsqlbwB8j9lkpQm7O3-LDteJn2Z6SqiWX2c=w2400" alt="Computer man" style="width:800px;height:300px;"/>
# <p style="border:4px solid violet;color:green;background-color:tan;">
#     <b>What is Balanced data?</b><br>
#     Balanced data refers to those types of datasets where the target class has an even distribution of observations, i.e all class label have equal number of observations in the dataset.</p>
# <p style="border:4px solid violet;color:green;background-color:tan;">
#     <b>What is Unbalanced data?</b><br>
#     Imbalanced data refers to those types of datasets where the target class has an uneven distribution of observations, i.e one class label has a very high number of observations and the other has a very low number of observations.</p>
#     </html>

# %% [markdown]
# ### Pie Chart shows that the target class is Unbalanced.<a class="anchor" id="sec2.8"></a>

# %% [markdown]
# <html>
# <p style="border:4px solid violet;color:indigo;background-color:tan">Pie chart tells that this is a case of <b>Unbalanced data</b> so I will SMOTE technique to oversample the data.</p>
# </html>

# %%
target_var=pd.crosstab(index=df['Class'],columns='% observations')
plt.pie(target_var['% observations'],labels=target_var['% observations'].index,autopct='%.0f%%')
plt.title('Class')
plt.show()

# %% [markdown]
# ### Count plot shows that the target class is imbalanced <a class="anchor" id="sec2.9"></a>

# %%
sns.barplot(x=target_var.index,y=target_var['% observations'])
plt.title('Class')
plt.show()

# %%
sns.scatterplot(x=df.V21,y=df.V22,hue=df.Class)
plt.show()
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %% [markdown]
# ### Feature Selection <a class="anchor" id="sec3"></a>

# %% [markdown]
# <html>
# <p style="color:chocolate;font-size:150%;">
#     <b>Feature Selection-</b></p>
# <p style="border:4px solid violet;color:green;background-color:tan;">
#     Feature selection methods are intended to reduce the number of input variables to those that are believed to be most useful to a model in order to predict the target variable..</p>
# <img src="https://lh6.googleusercontent.com/exNj6JGWZNAzyB8XXd1LM5FrgMGbfyV09Qgts5bPJA14O7-8AqATF9suuWqYo6oYhOk=w2400" alt="Computer man" style="width:800px;height:300px;"/>
#  </html>

# %% [markdown]
# <html>
# <p style="border:4px solid violet;color:green;background-color:tan;">
#     In our dataset we have numerical Input variable and Categorical Output variable.so we will use <b>ANOVA</b> for the feature selection.<br><br>
#     <b>ANOVA</b>:The ANOVA test allows a comparison of more than two groups at the same time to determine whether a relationship exists between them. The result of the ANOVA formula, the F statistic (also called the F-ratio), allows for the analysis of multiple groups of data to determine the variability between samples and within samples.</p>
#  </html>

# %%
from sklearn.feature_selection import f_classif#ANOVA

# %%
fs =f_classif(X,y)

# %%
selected_var=[]
print('if p-value<0.05 : Reject the null hypothesis \nif p-value>0.05 :Fail to relect the null hypothesis.\n')
for i,j in enumerate(X.columns):
    print(f'Null hypothesis: There is no significant difference between the mean {j} among different groups of Class.')
    print(f'Alternate Hypothesis: There is a significant difference between the mean {j} among different groups of Class.')
    if fs[1][i]<0.05:#p-values<0.05
        print(f'{j} : Reject the null hypothesis.\n')
    else:
        print(f'{j} : Fail to reject the null hypothesis.\n')
        selected_var.append(j)
# Out:
# if p-value<0.05 : Reject the null hypothesis
# if p-value>0.05 :Fail to relect the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean Time among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean Time among different groups of Class.
# Time : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V1 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V1 among different groups of Class.
# V1 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V2 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V2 among different groups of Class.
# V2 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V3 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V3 among different groups of Class.
# V3 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V4 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V4 among different groups of Class.
# V4 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V5 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V5 among different groups of Class.
# V5 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V6 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V6 among different groups of Class.
# V6 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V7 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V7 among different groups of Class.
# V7 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V8 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V8 among different groups of Class.
# V8 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V9 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V9 among different groups of Class.
# V9 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V10 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V10 among different groups of Class.
# V10 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V11 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V11 among different groups of Class.
# V11 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V12 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V12 among different groups of Class.
# V12 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V13 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V13 among different groups of Class.
# V13 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V14 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V14 among different groups of Class.
# V14 : Fail to reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V15 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V15 among different groups of Class.
# V15 : Fail to reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V16 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V16 among different groups of Class.
# V16 : Fail to reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V17 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V17 among different groups of Class.
# V17 : Fail to reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V18 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V18 among different groups of Class.
# V18 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V19 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V19 among different groups of Class.
# V19 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V20 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V20 among different groups of Class.
# V20 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V21 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V21 among different groups of Class.
# V21 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V22 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V22 among different groups of Class.
# V22 : Fail to reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V23 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V23 among different groups of Class.
# V23 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V24 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V24 among different groups of Class.
# V24 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V25 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V25 among different groups of Class.
# V25 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V26 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V26 among different groups of Class.
# V26 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V27 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V27 among different groups of Class.
# V27 : Fail to reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean V28 among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean V28 among different groups of Class.
# V28 : Reject the null hypothesis.
#
# Null hypothesis: There is no significant difference between the mean Amount among different groups of Class.
# Alternate Hypothesis: There is a significant difference between the mean Amount among different groups of Class.
# Amount : Reject the null hypothesis.

# %% [markdown]
# <html>
# <p style="border:4px solid violet;color:green;background-color:tan;">
#     Those features have been selected in which there is no significant difference between the mean among different groups of Class Variable.</p>
#     </html>

# %%
X=X[selected_var]

# %% [markdown]
# ### SMOTE(Synthetic Minority Oversampling Technique)<a class="anchor" id="sec8"></a>

# %% [markdown]
# <html>
# <p style="color:chocolate;font-size:150%;">
#     <b>Under Sampling and Over Sampling-</b></p>
#     <img src="https://lh6.googleusercontent.com/n33kWCxulUum6gl_SSImC7TGtBUs71b-BjOrzv1DPw0PJ8K7QPuo55B4DntBhuLL_RU=w2400" alt="Computer man" style="width:800px;height:300px;"/>
# <p style="border:4px solid violet;color:green;background-color:tan;">
#     <b>What is SMOTE ?</b><br>
#     Synthetic Minority Oversampling Technique or SMOTE is a technique to oversample the minority class. Simply adding duplicate records of minority class often don’t add any new information to the model. In SMOTE new instances are synthesized from the existing data. If we explain it in simple words, SMOTE looks into minority class instances and use k nearest neighbor to select a random nearest neighbor, and a synthetic instance is created randomly in feature space.</p>
#     </html>

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(sampling_strategy='auto', random_state=42)

# %%
X,y=sm.fit_resample(X,y)

# %% [markdown]
# ### Count plot after applying SMOTE

# %%
sns.countplot(y)
plt.show()
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(x=X.V27,y=X.V22,hue=y)
plt.show()
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Splitting our dataset into train and test set <a class="anchor" id="sec4"></a>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,stratify=y,random_state=0)

# %% [markdown]
# ### Feature Scaling <a class="anchor" id="sec5"></a>

# %% [markdown]
# <html>
# <p style="color:chocolate;font-size:150%;text-align:center">
#     <b>Feature Scaling-</b></p>
# <p style="border:4px solid violet;color:green;background-color:tan;text-align:center">
#     <b>What is Normalization?</b><br>
#     Normalization is a scaling technique in which values are shifted and rescaled so that they end up ranging between 0 and 1. It is also known as Min-Max scaling.<br>
#     <img src="https://lh3.googleusercontent.com/q9a09LIGXoRO_1bdgFw0C3WcjyEhpDnJ3C8COL65yn0gWhRTtFm5US-Q33aAQujuETQ=w2400" alt="Computer man" style="width:800px;height:200px;"/>
#     <b>What is Standardization?</b><br>
#     Standardization is another scaling technique where the values are centered around the mean with a unit standard deviation. This means that the mean of the attribute becomes zero and the resultant distribution has a unit standard deviation.
#         <img src="https://lh6.googleusercontent.com/_y4dtry_8ImYjqLTXcH68ZpB1--Iea2n2m08d-GLpbTQ4VSREwy3v1PcX8dGQwLE9PE=w2400" alt="Computer man" style="width:800px;height:200px;"/></p>

# %% [markdown]
# <html>
# <p style="border:4px solid violet;color:green;background-color:tan;">
#     Here we are going to use <b>Standardization</b>.</p>
#     </html>

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %% [markdown]
# ## Modeling <a class="anchor" id="sec6"></a>

# %% [markdown]
# ### Performance Measures for Multi-Class

# %% [markdown]
# <html>
# <p style="border:4px solid violet;color:green;background-color:tan;text-align:center">
#     <b>Confusion Matrix-</b><br>
#     <img src="https://lh6.googleusercontent.com/WJEnoqTTOGL2LQynBs3nG4uA47_UB5imRkgfTKVwYaTq8Zmmi-_Ns7SEPI90VVjt5-I=w2400" alt="Computer man" style="width:800px;height:300px;"/>
#     <br>
#     <b>Other Multiclass Classification Metrics:</b><br>
#     <img src="https://lh6.googleusercontent.com/rLIeVDOU5r4vAL1wPwWM0NtxKMUTzgkgOVZkkGiXxMC1VtCimZSrwLTYeEOap5Js8MY=w2400" alt="Computer man" style="width:800px;height:300px;"/>
#     </p>
#     </html>

# %% [markdown]
# ### K-fold Cross Validation

# %% [markdown]
# <html>
# <p style="color:chocolate;font-size:150%;">
#     <b>K-fold Cross validation-</b></p>
# <p style="border:4px solid violet;color:green;background-color:tan;text-align:center">
#     <b>What is Cross Validation?</b><br>
#     Cross-validation is a technique in which we train our model using the subset of the data-set and then evaluate using the complementary subset of the data-set.<br>
#     <img src="https://lh6.googleusercontent.com/sp2oloxXrxErMlLFkU3p0TqWYUh4O-9OjhQxBk8RcbKyYrxfPSSfGqw4KU61Vw_Qq7A=w2400" alt="Computer man" style="width:800px;height:400px;"/>
#     </html>

# %%
#importing different classification models
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score,f1_score
from sklearn.metrics import classification_report
from xgboost import XGBClassifier

# %%
#creating dictionary for storing different models accuracy
model_comparison={}

# %% [markdown]
# ### Decision Tree <a class="anchor" id="sec6.1"></a>

# %%
classifier=DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)
print(f"Model Accuracy : {accuracy_score(y_pred,y_test)*100:.2f}%")
print(f"Model F1-Score : {f1_score(y_pred,y_test,average='weighted')*100:.2f}%")
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
print(classification_report(y_pred,y_test,zero_division=1))
model_comparison['Decision Tree']=[accuracy_score(y_pred,y_test),f1_score(y_pred,y_test,average='weighted'),(accuracies.mean()),(accuracies.std())]
# Out:
# Model Accuracy : 99.69%
# Model F1-Score : 99.69%
# Cross Val Accuracy: 99.64 %
# Cross Val Standard Deviation: 0.01 %
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56733
#            1       1.00      1.00      1.00     56993
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726

# %% [markdown]
# ### KNN <a class="anchor" id="sec6.2"></a>

# %%
classifier=DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)
print(f"Model Accuracy : {accuracy_score(y_pred,y_test)*100:.2f}%")
print(f"Model F1-Score : {f1_score(y_pred,y_test,average='weighted')*100:.2f}%")
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
print(classification_report(y_pred,y_test,zero_division=1))
model_comparison['KNN']=[accuracy_score(y_pred,y_test),f1_score(y_pred,y_test,average='weighted'),(accuracies.mean()),(accuracies.std())]
# Out:
# Model Accuracy : 99.69%
# Model F1-Score : 99.69%
# Cross Val Accuracy: 99.64 %
# Cross Val Standard Deviation: 0.01 %
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56733
#            1       1.00      1.00      1.00     56993
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726

# %% [markdown]
# ### Naive Bayes <a class="anchor" id="sec6.3"></a>

# %%
classifier=GaussianNB()
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)
print(f"Model Accuracy : {accuracy_score(y_pred,y_test)*100:.2f}%")
print(f"Model F1-Score : {f1_score(y_pred,y_test,average='weighted')*100:.2f}%")
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
print(classification_report(y_pred,y_test,zero_division=1))
model_comparison['Naive Bayes']=[accuracy_score(y_pred,y_test),f1_score(y_pred,y_test,average='weighted'),(accuracies.mean()),(accuracies.std())]
# Out:
# Model Accuracy : 72.49%
# Model F1-Score : 72.70%
# Cross Val Accuracy: 72.70 %
# Cross Val Standard Deviation: 0.03 %
#               precision    recall  f1-score   support
#
#            0       0.64      0.77      0.70     46792
#            1       0.81      0.69      0.75     66934
#
#     accuracy                           0.72    113726
#    macro avg       0.72      0.73      0.72    113726
# weighted avg       0.74      0.72      0.73    113726

# %% [markdown]
# ### Random Forest <a class="anchor" id="sec6.5"></a>

# %%
classifier=RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)
print(f"Model Accuracy : {accuracy_score(y_pred,y_test)*100:.2f}%")
print(f"Model F1-Score : {f1_score(y_pred,y_test,average='weighted')*100:.2f}%")
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
print(classification_report(y_pred,y_test,zero_division=1))
model_comparison['Random Forest']=[accuracy_score(y_pred,y_test),f1_score(y_pred,y_test,average='weighted'),(accuracies.mean()),(accuracies.std())]
# Out:
# Model Accuracy : 99.90%
# Model F1-Score : 99.90%
# Cross Val Accuracy: 99.88 %
# Cross Val Standard Deviation: 0.01 %
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56797
#            1       1.00      1.00      1.00     56929
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726

# %% [markdown]
# ### Xg Boost <a class="anchor" id="sec6.6"></a>

# %%
classifier = XGBClassifier()
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)
print(f"Model Accuracy : {accuracy_score(y_pred,y_test)*100:.2f}%")
print(f"Model F1-Score : {f1_score(y_pred,y_test,average='weighted')*100:.2f}%")
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
print(classification_report(y_pred,y_test,zero_division=1))
model_comparison['Xg Boost']=[accuracy_score(y_pred,y_test),f1_score(y_pred,y_test,average='weighted'),(accuracies.mean()),(accuracies.std())]
# Out:
# Model Accuracy : 99.38%
# Model F1-Score : 99.38%
# Cross Val Accuracy: 99.42 %
# Cross Val Standard Deviation: 0.02 %
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     56399
#            1       1.00      0.99      0.99     57327
#
#     accuracy                           0.99    113726
#    macro avg       0.99      0.99      0.99    113726
# weighted avg       0.99      0.99      0.99    113726

# %% [markdown]
# ### Model Comparison <a class="anchor" id="sec7"></a>

# %%
Model_com_df=pd.DataFrame(model_comparison).T
Model_com_df.columns=['Model Accuracy','Model F1-Score','CV Accuracy','CV std']
Model_com_df=Model_com_df.sort_values(by='Model F1-Score',ascending=False)
Model_com_df.style.format("{:.2%}").background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_917c5_row0_col0, #T_917c5_row0_col1, #T_917c5_row0_col2, #T_917c5_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_917c5_row0_col3 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_917c5_row1_col0, #T_917c5_row1_col1, #T_917c5_row1_col2, #T_917c5_row2_col0, #T_917c5_row2_col1, #T_917c5_row2_col2 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_917c5_row1_col3, #T_917c5_row2_col3, #T_917c5_row4_col0, #T_917c5_row4_col1, #T_917c5_row4_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_917c5_row3_col0, #T_917c5_row3_col1, #T_917c5_row3_col2 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_917c5_row3_col3 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_917c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_917c5_level0_col0" class="col_heading level0 col0" >Model Accuracy</th>
#       <th id="T_917c5_level0_col1" class="col_heading level0 col1" >Model F1-Score</th>
#       <th id="T_917c5_level0_col2" class="col_heading level0 col2" >CV Accuracy</th>
#       <th id="T_917c5_level0_col3" class="col_heading level0 col3" >CV std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_917c5_level0_row0" class="row_heading level0 row0" >Random Forest</th>
#       <td id="T_917c5_row0_col0" class="data row0 col0" >99.90%</td>
#       <td id="T_917c5_row0_col1" class="data row0 col1" >99.90%</td>
#       <td id="T_917c5_row0_col2" class="data row0 col2" >99.88%</td>
#       <td id="T_917c5_row0_col3" class="data row0 col3" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_917c5_level0_row1" class="row_heading level0 row1" >Decision Tree</th>
#       <td id="T_917c5_row1_col0" class="data row1 col0" >99.69%</td>
#       <td id="T_917c5_row1_col1" class="data row1 col1" >99.69%</td>
#       <td id="T_917c5_row1_col2" class="data row1 col2" >99.64%</td>
#       <td id="T_917c5_row1_col3" class="data row1 col3" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_917c5_level0_row2" class="row_heading level0 row2" >KNN</th>
#       <td id="T_917c5_row2_col0" class="data row2 col0" >99.69%</td>
#       <td id="T_917c5_row2_col1" class="data row2 col1" >99.69%</td>
#       <td id="T_917c5_row2_col2" class="data row2 col2" >99.64%</td>
#       <td id="T_917c5_row2_col3" class="data row2 col3" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_917c5_level0_row3" class="row_heading level0 row3" >Xg Boost</th>
#       <td id="T_917c5_row3_col0" class="data row3 col0" >99.38%</td>
#       <td id="T_917c5_row3_col1" class="data row3 col1" >99.38%</td>
#       <td id="T_917c5_row3_col2" class="data row3 col2" >99.42%</td>
#       <td id="T_917c5_row3_col3" class="data row3 col3" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_917c5_level0_row4" class="row_heading level0 row4" >Naive Bayes</th>
#       <td id="T_917c5_row4_col0" class="data row4 col0" >72.49%</td>
#       <td id="T_917c5_row4_col1" class="data row4 col1" >72.70%</td>
#       <td id="T_917c5_row4_col2" class="data row4 col2" >72.70%</td>
#       <td id="T_917c5_row4_col3" class="data row4 col3" >0.03%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Maximum Accuracies in each Column <a class="anchor" id="sec7.1"></a>

# %%
Model_com_df.style.highlight_max().set_caption("Maximum Score in each Column").format("{:.2%}")
# Out:
# <style type="text/css">
# #T_7439f_row0_col0, #T_7439f_row0_col1, #T_7439f_row0_col2, #T_7439f_row4_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_7439f">
#   <caption>Maximum Score in each Column</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7439f_level0_col0" class="col_heading level0 col0" >Model Accuracy</th>
#       <th id="T_7439f_level0_col1" class="col_heading level0 col1" >Model F1-Score</th>
#       <th id="T_7439f_level0_col2" class="col_heading level0 col2" >CV Accuracy</th>
#       <th id="T_7439f_level0_col3" class="col_heading level0 col3" >CV std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7439f_level0_row0" class="row_heading level0 row0" >Random Forest</th>
#       <td id="T_7439f_row0_col0" class="data row0 col0" >99.90%</td>
#       <td id="T_7439f_row0_col1" class="data row0 col1" >99.90%</td>
#       <td id="T_7439f_row0_col2" class="data row0 col2" >99.88%</td>
#       <td id="T_7439f_row0_col3" class="data row0 col3" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_7439f_level0_row1" class="row_heading level0 row1" >Decision Tree</th>
#       <td id="T_7439f_row1_col0" class="data row1 col0" >99.69%</td>
#       <td id="T_7439f_row1_col1" class="data row1 col1" >99.69%</td>
#       <td id="T_7439f_row1_col2" class="data row1 col2" >99.64%</td>
#       <td id="T_7439f_row1_col3" class="data row1 col3" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_7439f_level0_row2" class="row_heading level0 row2" >KNN</th>
#       <td id="T_7439f_row2_col0" class="data row2 col0" >99.69%</td>
#       <td id="T_7439f_row2_col1" class="data row2 col1" >99.69%</td>
#       <td id="T_7439f_row2_col2" class="data row2 col2" >99.64%</td>
#       <td id="T_7439f_row2_col3" class="data row2 col3" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_7439f_level0_row3" class="row_heading level0 row3" >Xg Boost</th>
#       <td id="T_7439f_row3_col0" class="data row3 col0" >99.38%</td>
#       <td id="T_7439f_row3_col1" class="data row3 col1" >99.38%</td>
#       <td id="T_7439f_row3_col2" class="data row3 col2" >99.42%</td>
#       <td id="T_7439f_row3_col3" class="data row3 col3" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_7439f_level0_row4" class="row_heading level0 row4" >Naive Bayes</th>
#       <td id="T_7439f_row4_col0" class="data row4 col0" >72.49%</td>
#       <td id="T_7439f_row4_col1" class="data row4 col1" >72.70%</td>
#       <td id="T_7439f_row4_col2" class="data row4 col2" >72.70%</td>
#       <td id="T_7439f_row4_col3" class="data row4 col3" >0.03%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Minimum Accuracies in each Column <a class="anchor" id="sec7.2"></a>

# %%
Model_com_df.style.highlight_min().set_caption("Minimum Score in each Column").format("{:.2%}")
# Out:
# <style type="text/css">
# #T_06f40_row1_col3, #T_06f40_row2_col3, #T_06f40_row4_col0, #T_06f40_row4_col1, #T_06f40_row4_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_06f40">
#   <caption>Minimum Score in each Column</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06f40_level0_col0" class="col_heading level0 col0" >Model Accuracy</th>
#       <th id="T_06f40_level0_col1" class="col_heading level0 col1" >Model F1-Score</th>
#       <th id="T_06f40_level0_col2" class="col_heading level0 col2" >CV Accuracy</th>
#       <th id="T_06f40_level0_col3" class="col_heading level0 col3" >CV std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06f40_level0_row0" class="row_heading level0 row0" >Random Forest</th>
#       <td id="T_06f40_row0_col0" class="data row0 col0" >99.90%</td>
#       <td id="T_06f40_row0_col1" class="data row0 col1" >99.90%</td>
#       <td id="T_06f40_row0_col2" class="data row0 col2" >99.88%</td>
#       <td id="T_06f40_row0_col3" class="data row0 col3" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_06f40_level0_row1" class="row_heading level0 row1" >Decision Tree</th>
#       <td id="T_06f40_row1_col0" class="data row1 col0" >99.69%</td>
#       <td id="T_06f40_row1_col1" class="data row1 col1" >99.69%</td>
#       <td id="T_06f40_row1_col2" class="data row1 col2" >99.64%</td>
#       <td id="T_06f40_row1_col3" class="data row1 col3" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_06f40_level0_row2" class="row_heading level0 row2" >KNN</th>
#       <td id="T_06f40_row2_col0" class="data row2 col0" >99.69%</td>
#       <td id="T_06f40_row2_col1" class="data row2 col1" >99.69%</td>
#       <td id="T_06f40_row2_col2" class="data row2 col2" >99.64%</td>
#       <td id="T_06f40_row2_col3" class="data row2 col3" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_06f40_level0_row3" class="row_heading level0 row3" >Xg Boost</th>
#       <td id="T_06f40_row3_col0" class="data row3 col0" >99.38%</td>
#       <td id="T_06f40_row3_col1" class="data row3 col1" >99.38%</td>
#       <td id="T_06f40_row3_col2" class="data row3 col2" >99.42%</td>
#       <td id="T_06f40_row3_col3" class="data row3 col3" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_06f40_level0_row4" class="row_heading level0 row4" >Naive Bayes</th>
#       <td id="T_06f40_row4_col0" class="data row4 col0" >72.49%</td>
#       <td id="T_06f40_row4_col1" class="data row4 col1" >72.70%</td>
#       <td id="T_06f40_row4_col2" class="data row4 col2" >72.70%</td>
#       <td id="T_06f40_row4_col3" class="data row4 col3" >0.03%</td>
#     </tr>
#   </tbody>
# </table>
